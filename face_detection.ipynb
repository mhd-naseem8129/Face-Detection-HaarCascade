# %% [markdown]
# <a href="https://colab.research.google.com/github/mhd-naseem8129/Face-Detection-HaarCascade/blob/main/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# 1. Load Haar Cascade classifier
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# 2. Load input image
image = cv2.imread("/content/faces.jpg")  # change image name if needed

# Check if image loaded properly
if image is None:
    print("Error: Image not found")
    exit()

# 3. Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 4. Detect faces
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

# 5. Draw bounding boxes around faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# 6. Display total face count
print(f"Number of faces detected: {len(faces)}")

# 7. Show output image
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of faces detected: 4
# <PIL.Image.Image image mode=RGB size=620x349>
